# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
v = np.loadtxt("output.txt")
v
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-37d803f69e93> in <module>
# ----> 1 v = np.loadtxt("output.txt")
#       2 v
#
# NameError: name 'np' is not defined

# %%
maxwell = stats.maxwell
_, bins, _ = plt.hist(v, 20, density=1, alpha=0.5)
maxwell = stats.maxwell

param1,param2 = maxwell.fit(v, floc=0)
best_fit_line = maxwell.pdf(bins, param1, param2)
plt.plot(bins, best_fit_line)

# %%
vi = np.loadtxt("output2.txt")
maxwell = stats.maxwell
_, bins, _ = plt.hist(vi, 20, density=1, alpha=0.5)
maxwell = stats.maxwell

param1,param2 = maxwell.fit(vi, floc=0)
best_fit_line = maxwell.pdf(bins, param1, param2)
plt.plot(bins, best_fit_line)

# %%
v = np.loadtxt("1particula.txt")
_, bins, _ = plt.hist(v, 20, density=1, alpha=0.5)
maxwell = stats.maxwell

param1,param2 = maxwell.fit(v, floc=0)
best_fit_line = maxwell.pdf(bins, param1, param2)
plt.plot(bins, best_fit_line)
